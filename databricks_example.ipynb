# %% [markdown]
# # 1. Build Classification Model
# First, you will need to prepare each of the input features. While age is a numeric feature, state and name are not. These need to be converted into numeric vectors before you can train the model. Use a StringIndexer along with the OneHotEncoderEstimator to convert the name, state, and sex columns into numeric vectors. Use the VectorAssembler to combine the name, state, and age vectors into a single features vector. Your final dataset should contain a column called features containing the prepared vector and a column called label containing the sex of the person.
#
# NOTE: my work in this notebook borrows heavily from https://docs.databricks.com/applications/machine-learning/mllib/binary-classification-mllib-pipelines.html.
#
# **NOTE** I only used one of the `.parquet` files because it took so long to run, the Databricks cluster stopped before the code ran (and that was only for the initial fitting). Even with only one file, it takes a long time to run and I recognize that the scores are all skewed as a result, but it shows that it works, which I believe is the ultimate objective.

# %%
# Imports
from pyspark.ml import Pipeline
from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import BinaryClassificationEvaluator
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Load The Data
# Again, I'm only loading one file. In a real-world scenario, I'd load all the files. If this were a dynamic model, I'd actually use Stream Processing to add new files periodically and re-run the model with a periodicity either equal to the stream flow, or something that makes sense for the given business context.

# %%
#dbutils.fs.rm('/FileStore/tables/baby-data', True) 
dbutils.fs.ls("/FileStore/tables/bn-parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">14</span><span class="ansired">]: </span>[FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00000_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-b639a.parquet&apos;, name=&apos;part_00000_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-b639a.parquet&apos;, size=1103223),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00001_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-7c1a0.parquet&apos;, name=&apos;part_00001_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-7c1a0.parquet&apos;, size=929588),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00002_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-d0281.parquet&apos;, name=&apos;part_00002_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-d0281.parquet&apos;, size=686924),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00003_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-807e7.parquet&apos;, name=&apos;part_00003_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-807e7.parquet&apos;, size=590445),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00004_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-c39fb.parquet&apos;, name=&apos;part_00004_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-c39fb.parquet&apos;, size=465697),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00005_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-d7947.parquet&apos;, name=&apos;part_00005_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-d7947.parquet&apos;, size=1029483),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00006_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-56d18.parquet&apos;, name=&apos;part_00006_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-56d18.parquet&apos;, size=1085917),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00007_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-cf41a.parquet&apos;, name=&apos;part_00007_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-cf41a.parquet&apos;, size=906527),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00008_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-fe2df.parquet&apos;, name=&apos;part_00008_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-fe2df.parquet&apos;, size=967808),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00009_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-f3051.parquet&apos;, name=&apos;part_00009_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-f3051.parquet&apos;, size=832675),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00010_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-c01de.parquet&apos;, name=&apos;part_00010_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-c01de.parquet&apos;, size=602325),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00011_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-b7b1a.parquet&apos;, name=&apos;part_00011_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-b7b1a.parquet&apos;, size=830745),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00012_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-ff1bd.parquet&apos;, name=&apos;part_00012_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-ff1bd.parquet&apos;, size=960939),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00013_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-1d940.parquet&apos;, name=&apos;part_00013_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-1d940.parquet&apos;, size=895216),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00014_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-04c6b.parquet&apos;, name=&apos;part_00014_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-04c6b.parquet&apos;, size=773380),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00015_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-661bd.parquet&apos;, name=&apos;part_00015_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-661bd.parquet&apos;, size=874157),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00016_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-1a242.parquet&apos;, name=&apos;part_00016_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-1a242.parquet&apos;, size=603983),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00017_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-5fd7f.parquet&apos;, name=&apos;part_00017_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-5fd7f.parquet&apos;, size=811912),
#  FileInfo(path=&apos;dbfs:/FileStore/tables/bn-parquet/part_00018_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-3ef31.parquet&apos;, name=&apos;part_00018_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-3ef31.parquet&apos;, size=1049377)]</div>

# %%
df = spark.read.parquet("/FileStore/tables/bn-parquet/part_00018_5eb32e4b_dc40_4002_8fc0_581dba1df650_c000_snappy-3ef31.parquet")
print((df.count(), len(df.columns)))
cols = df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(8507847, 4)
# </div>

# %% [markdown]
# ## Transform Data
# A rew things are happening here:
#
# 1. Columns are setup for the one-hot encoding since OHE adds columns for each categorical value
# 2. The OHE is done for name and state
# 3. The label is set for sex, which itself is encoded

# %%
categoricalColumns = ["name", "state"]
stages = [] # stages in our Pipeline
for categoricalCol in categoricalColumns:
    # Category Indexing with StringIndexer
    stringIndexer = StringIndexer(inputCol=categoricalCol, outputCol=categoricalCol + "Index")
    # Use OneHotEncoder to convert categorical variables into binary SparseVectors
    encoder = OneHotEncoderEstimator(inputCols=[stringIndexer.getOutputCol()], outputCols=[categoricalCol + "classVec"])
    # Add stages.  These are not run here, but will run all at once later on.
    stages += [stringIndexer, encoder]

label_stringIdx = StringIndexer(inputCol="sex", outputCol="label")
stages += [label_stringIdx]

numericCols = ["age"]
assemblerInputs = [c + "classVec" for c in categoricalColumns] + numericCols
assembler = VectorAssembler(inputCols=assemblerInputs, outputCol="features")
stages += [assembler]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
partialPipeline = Pipeline().setStages(stages)
pipelineModel = partialPipeline.fit(df)
preppedDataDF = pipelineModel.transform(df)
print((preppedDataDF.count(), len(preppedDataDF.columns)))
print(preppedDataDF.describe)
print(preppedDataDF.head(10))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(8507847, 10)
# &lt;bound method DataFrame.describe of DataFrame[name: string, state: string, sex: string, age: int, nameIndex: double, nameclassVec: vector, stateIndex: double, stateclassVec: vector, label: double, features: vector]&gt;
# [Row(name=&apos;Phillip&apos;, state=&apos;MO&apos;, sex=&apos;M&apos;, age=53, nameIndex=210.0, nameclassVec=SparseVector(6752, {210: 1.0}), stateIndex=1.0, stateclassVec=SparseVector(3, {1: 1.0}), label=0.0, features=SparseVector(6756, {210: 1.0, 6753: 1.0, 6755: 53.0})), Row(name=&apos;Phillip&apos;, state=&apos;MO&apos;, sex=&apos;M&apos;, age=53, nameIndex=210.0, nameclassVec=SparseVector(6752, {210: 1.0}), stateIndex=1.0, stateclassVec=SparseVector(3, {1: 1.0}), label=0.0, features=SparseVector(6756, {210: 1.0, 6753: 1.0, 6755: 53.0})), Row(name=&apos;Phillip&apos;, state=&apos;MO&apos;, sex=&apos;M&apos;, age=53, nameIndex=210.0, nameclassVec=SparseVector(6752, {210: 1.0}), stateIndex=1.0, stateclassVec=SparseVector(3, {1: 1.0}), label=0.0, features=SparseVector(6756, {210: 1.0, 6753: 1.0, 6755: 53.0})), Row(name=&apos;Phillip&apos;, state=&apos;MO&apos;, sex=&apos;M&apos;, age=53, nameIndex=210.0, nameclassVec=SparseVector(6752, {210: 1.0}), stateIndex=1.0, stateclassVec=SparseVector(3, {1: 1.0}), label=0.0, features=SparseVector(6756, {210: 1.0, 6753: 1.0, 6755: 53.0})), Row(name=&apos;Phillip&apos;, state=&apos;MO&apos;, sex=&apos;M&apos;, age=53, nameIndex=210.0, nameclassVec=SparseVector(6752, {210: 1.0}), stateIndex=1.0, stateclassVec=SparseVector(3, {1: 1.0}), label=0.0, features=SparseVector(6756, {210: 1.0, 6753: 1.0, 6755: 53.0})), Row(name=&apos;Phillip&apos;, state=&apos;MO&apos;, sex=&apos;M&apos;, age=53, nameIndex=210.0, nameclassVec=SparseVector(6752, {210: 1.0}), stateIndex=1.0, stateclassVec=SparseVector(3, {1: 1.0}), label=0.0, features=SparseVector(6756, {210: 1.0, 6753: 1.0, 6755: 53.0})), Row(name=&apos;Phillip&apos;, state=&apos;MO&apos;, sex=&apos;M&apos;, age=53, nameIndex=210.0, nameclassVec=SparseVector(6752, {210: 1.0}), stateIndex=1.0, stateclassVec=SparseVector(3, {1: 1.0}), label=0.0, features=SparseVector(6756, {210: 1.0, 6753: 1.0, 6755: 53.0})), Row(name=&apos;Phillip&apos;, state=&apos;MO&apos;, sex=&apos;M&apos;, age=53, nameIndex=210.0, nameclassVec=SparseVector(6752, {210: 1.0}), stateIndex=1.0, stateclassVec=SparseVector(3, {1: 1.0}), label=0.0, features=SparseVector(6756, {210: 1.0, 6753: 1.0, 6755: 53.0})), Row(name=&apos;Phillip&apos;, state=&apos;MO&apos;, sex=&apos;M&apos;, age=53, nameIndex=210.0, nameclassVec=SparseVector(6752, {210: 1.0}), stateIndex=1.0, stateclassVec=SparseVector(3, {1: 1.0}), label=0.0, features=SparseVector(6756, {210: 1.0, 6753: 1.0, 6755: 53.0})), Row(name=&apos;Phillip&apos;, state=&apos;MO&apos;, sex=&apos;M&apos;, age=53, nameIndex=210.0, nameclassVec=SparseVector(6752, {210: 1.0}), stateIndex=1.0, stateclassVec=SparseVector(3, {1: 1.0}), label=0.0, features=SparseVector(6756, {210: 1.0, 6753: 1.0, 6755: 53.0}))]
# </div>

# %% [markdown]
# ## Useless LR
# I left this here for some reason that I'm not quite sure of. It does a fit on the prepped data, but the model is never used because in the next steps, the data is split into test and train and the LR is re-built.

# %%
# Fit model to prepped data
lrModel = LogisticRegression().fit(preppedDataDF)

# ROC for training data
display(lrModel, preppedDataDF, "ROC")
display(lrModel, preppedDataDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fitted values</th><th>residuals</th></tr></thead><tbody><tr><td>-15.691365487314451</td><td>-1.5322389173313912E-7</td></tr><tr><td>-11.330694571902546</td><td>-1.1998768112439006E-5</td></tr><tr><td>-14.709322095219555</td><td>-4.0909333487358165E-7</td></tr><tr><td>-20.6251670358232</td><td>-1.1030717632373219E-9</td></tr><tr><td>-17.920270910658985</td><td>-1.649397082844531E-8</td></tr><tr><td>-16.95458223921644</td><td>-4.332299491363916E-8</td></tr><tr><td>-14.527364286673585</td><td>-4.907334258772004E-7</td></tr><tr><td>-17.919169571813025</td><td>-1.6512146285774295E-8</td></tr><tr><td>-19.659443944302346</td
td><td>2.2592067209448174E-5</td></tr><tr><td>11.48190366000116</td><td>1.0314973556635465E-5</td></tr><tr><td>10.969569643403773</td><td>1.7217455036910856E-5</td></tr><tr><td>11.5779462977281</td><td>9.370391613749973E-6</td></tr><tr><td>11.899264126740322</td><td>6.795357346489617E-6</td></tr><tr><td>-1.6402040490920822</td><td>0.8375627005008977</td></tr><tr><td>-12.490807911336375</td><td>-3.7610526772355896E-6</td></tr><tr><td>-12.28164705605576</td><td>-4.636032175750824E-6</td></tr><tr><td>-4.687340043743166</td><td>-0.009127083884833562</td></tr><tr><td>-5.4474941830477706</td><td>-0.004288612529489027</td></tr><tr ...

# %% [markdown]
# ## Split Data
# This is a simple split for test and train. The data is so strange that I'm not really sure if it's even value. For example, it looks like the exact same observations appear many times in the `.parquet` files. Regardless, the data here is a 70%/30% split, train to test.

# %%
selectedcols = ["label", "features"] + cols
dataset = preppedDataDF.select(selectedcols)
display(dataset)
(trainingData, testData) = dataset.randomSplit([0.7, 0.3], seed=100)
print(trainingData.count())
print(testData.count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>label</th><th>features</th><th>name</th><th>state</th><th>sex</th><th>age</th></tr></thead><tbody><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td><td>M</td><td>53</td></tr><tr><td>0.0</td><td>List(0, 6756, List(210, 6753, 6755), List(1.0, 1.0, 53.0))</td><td>Phillip</td><td>MO</td>< ...

# %% [markdown]
# # 2. Fit and Evaluate Model
# ## First Build the Model
# The logistic regression model is fit with the training data and then run against the test data. The output shows not only the predictions, but also the probability for each option (1 = Male, 2 = Female). Given the weird data, the model is likely pretty accurate, but not necessarily predictive with out-of-sample data. Without statistical evidence one way or another, my intuition says the data results in an overfitted model.

# %%
# Create initial LogisticRegression model
lr = LogisticRegression(labelCol="label", featuresCol="features", maxIter=10, regParam=0.3, elasticNetParam=0.8)
# Train model with Training Data
lrModel = lr.fit(trainingData)

predictions = lrModel.transform(testData)
selected = predictions.select("label", "prediction", "probability", "age", "name", "state")
display(selected)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>label</th><th>prediction</th><th>probability</th><th>age</th><th>name</th><th>state</th></tr></thead><tbody><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>56</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>60</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>60</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>60</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>61</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>61</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>61</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>62</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>62</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>63</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>65</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>65</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>65</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>66</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>66</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>67</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>67</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>68</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>68</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>68</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>68</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>70</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>70</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>70</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>71</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>72</td><td>Mary</td><td>MS</td></tr><tr><td>0.0</td><td>0.0</td><td>List(1, 2, List(), List(0.5231280822547849, 0.476871917745215))</td><td>72</td><td>Mary</td><td>MS</t ...

# %% [markdown]
# ## Evaluation
# The area under the curve is quite good at `82.44%`, but again, this seems like the result of an overfitted model based on flawed (manufactured) data. That could be totally false, but just looking at the repeated observations within the files leads me to this theory.
#
# A great deal more would be required to move this forward:
# 1. Build deep desriptive analytics for the data to see if it's flawed. If so, rebuild it to more accurately represent the real population.
# 2. Use cross-fold validation for data split.
# 3. Use hyper-parameter tuning for the LR model.
# 4. Try other algorithms, especially an ensemble such as Random Forest.

# %%
# Evaluate model
evaluator = BinaryClassificationEvaluator(rawPredictionCol="rawPrediction")
results = evaluator.evaluate(predictions)
print(results)
evaluator.getMetricName()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0.8244182723083767
# <span class="ansired">Out[</span><span class="ansired">36</span><span class="ansired">]: </span>&apos;areaUnderROC&apos;</div>
